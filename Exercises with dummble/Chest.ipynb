# %% [markdown]
# # List Of chest exercises

# %%
from IPython.display import IFrame


IFrame('https://tomsguide.com/news/10-of-the-best-dumbbell-chest-exercises/',width=800,height=450)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 4
#       1 from IPython.display import IFrame
# ----> 4 IFrame('https://tomsguide.com/news/10-of-the-best-dumbbell-chest-exercises/')
#
# TypeError: IFrame.__init__() missing 2 required positional arguments: 'width' and 'height'

# %% [markdown]
# ## 1. DUMBBELL CHEST PRESS

# %%
from IPython.display import IFrame
from IPython.display import YouTubeVideo

# IFrame('https://tomsguide.com/news/10-of-the-best-dumbbell-chest-exercises',width=800,height=450)\
YouTubeVideo('QsYre__-aro', width=950,height=475)

# %%
# import glob
# from IPython.display import Image, display
# for imageName in glob.glob('yourpath/*.jpg'): #assuming JPG
#     display(Image(filename=imageName))
#     print(imageName)

# %%
import os
cwd = os.getcwd()
cwd
# Out:
# '/Users/imans/Desktop/learning/Exercises with dummble'

# %%
import os
from IPython.display import Image

desired_path = '/Users/imans/Desktop/learning/photos/Exercises with dummble/chest'

# Assuming your photo is named 'example.jpg'
photo_path = os.path.join(desired_path, 'chest-press.png')

# Display the photo
Image(filename=photo_path)

# %% [markdown]
# ### 1. werdesdw

# %% [markdown]
# 2. DUMBBELL CHEST FLY
# 3. DUMBBELL PULLOVER
# 4. DUMBBELL SVEND PRESS
# 5. STANDING CROSS-BODY DUMBBELL RAISE
# 6. CRUSH GRIP DUMBBELL PRESS
# 7. DECLINE DUMBBELL CHEST PRESS
# 8. INCLINE DUMBBELL CHEST PRESS
# 9. DUMBBELL PUSH UP
# 10. REVERSE GRIP DUMBBELL CHEST PRESS
